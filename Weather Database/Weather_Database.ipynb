# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs
#The zip object packs each pair of lats and lngs having the same index in their respective array into a tuple

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
 # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
print(cities)
# Out:
# ['ryotsu', 'sitka', 'asau', 'albany', 'port alfred', 'barrow', 'barentsburg', 'salme', 'jamestown', 'faanui', 'busselton', 'atar', 'komsomolskiy', 'ushuaia', 'chaozhou', 'paamiut', 'vieste', 'ierapetra', 'hilo', 'fortuna', 'klaksvik', 'mahajanga', 'shimoda', 'butaritari', 'punta arenas', 'rikitea', 'mastic beach', 'puerto ayora', 'barcelona', 'saint-francois', 'belushya guba', 'hasaki', 'lexington', 'bengkulu', 'taolanaro', 'mataura', 'doctor pedro p. pena', 'ampanihy', 'masumbwe', 'kahta', 'olinda', 'arraial do cabo', 'bhikangaon', 'narsaq', 'port-gentil', 'serov', 'jibuti', 'shumikha', 'vaini', 'hamilton', 'maragogi', 'souillac', 'bantul', 'kapaa', 'nizhniy kuranakh', 'xichang', 'charters towers', 'attawapiskat', 'le port', 'tsihombe', 'tecoanapa', 'saint-philippe', 'yellowknife', 'tual', 'riyadh', 'kodiak', 'hobart', 'aripuana', 'deputatskiy', 'east london', 'dikson', 'clyde river', 'nikolskoye', 'lavrentiya', 'touros', 'mapastepec', 'cape town', 'gewane', 'sobolevo', 'georgetown', 'tuatapere', 'pacific grove', 'tanabe', 'morondava', 'khatanga', 'cidreira', 'celestun', 'sentyabrskiy', 'nantucket', 'bluff', 'taoudenni', 'santo antonio do taua', 'rawson', 'vila franca do campo', 'la rioja', 'ust-kuyga', 'verkhoyansk', 'tumannyy', 'mazamari', 'togur', 'pochutla', 'hermanus', 'castro', 'kuala terengganu', 'buraydah', 'cabo san lucas', 'iqaluit', 'carutapera', 'saskylakh', 'bukachacha', 'ponta do sol', 'tuktoyaktuk', 'mount gambier', 'khorinsk', 'hirara', 'katsuura', 'hope', 'otradnoye', 'lasa', 'wuwei', 'nanpiao', 'yumen', 'sao jose do rio pardo', 'calabar', 'atuona', 'kardla', 'gardendale', 'naryan-mar', 'yarkovo', 'kalikapur', 'mar del plata', 'biak', 'beringovskiy', 'russell', 'new norfolk', 'nizhneyansk', 'valparaiso', 'kendari', 'arari', 'nome', 'candawaga', 'richards bay', 'san quintin', 'jamame', 'mahadday weyne', 'avarua', 'chikoy', 'amboasary', 'flinders', 'sarangani', 'domoni', 'airai', 'naantali', 'pasinler', 'lebu', 'erzincan', 'qaanaaq', 'longyearbyen', 'palmer', 'husavik', 'bridgetown', 'codrington', 'pisco', 'korla', 'bredasdorp', 'north bend', 'ostrovnoy', 'bindura', 'sao filipe', 'roebourne', 'tiznit', 'kutum', 'bethel', 'ozgon', 'chuy', 'biltine', 'galgani', 'padang', 'charlottesville', 'tiksi', 'esperance', 'ust-abakan', 'illoqqortoormiut', 'springbok', 'yaounde', 'presidente medici', 'sesheke', 'tazovskiy', 'provideniya', 'luderitz', 'amderma', 'uyemskiy', 'egvekinot', 'ndago', 'victoria', 'omsukchan', 'gujar khan', 'maldonado', 'neuquen', 'leningradskiy', 'kaoma', 'adrar', 'palombara sabina', 'vangaindrano', 'bambous virieux', 'torbay', 'azimur', 'chaman', 'ribeira grande', 'warqla', 'lodwar', 'achisay', 'bathsheba', 'nawabganj', 'isangel', 'mys shmidta', 'saravan', 'caravelas', 'cherskiy', 'olutanga', 'port macquarie', 'namie', 'acarau', 'sao mateus', 'moses lake', 'ca mau', 'tuggurt', 'semirom', 'aginskoye', 'sedelnikovo', 'louisbourg', 'petropavlovsk-kamchatskiy', 'geraldton', 'constitucion', 'sredneuralsk', 'bandundu', 'axim', 'sao jose da coroa grande', 'acapulco', 'port blair', 'gigmoto', 'selma', 'vila velha', 'norman wells', 'mana', 'codajas', 'kenai', 'vao', 'hithadhoo', 'abay', 'huancabamba', 'bilma', 'huambo', 'hami', 'soyo', 'elat', 'te anau', 'necochea', 'galveston', 'bonthe', 'comodoro rivadavia', 'bonavista', 'mantua', 'skjaerhollen', 'enzan', 'tasiilaq', 'olafsvik', 'sioux lookout', 'severo-kurilsk', 'kruisfontein', 'thai binh', 'filadelfia', 'otavi', 'koygorodok', 'mount isa', 'opuwo', 'bucak', 'chokurdakh', 'kaitangata', 'bar harbor', 'shenkursk', 'nardaran', 'samusu', 'srednekolymsk', 'zabid', 'umm lajj', 'ostersund', 'formoso do araguaia', 'los llanos de aridane', 'duncan', 'glendive', 'aykhal', 'namibe', 'port elizabeth', 'bangangte', 'margate', 'naranjal', 'alice springs', 'noyabrsk', 'bignona', 'minas', 'saint-augustin', 'kenora', 'hambantota', 'luau', 'dejen', 'metehara', 'hobyo', 'honiara', 'babushkin', 'malwan', 'mahebourg', 'klyuchi', 'gorno-altaysk', 'tamiahua', 'zaysan', 'aflu', ...

# %%
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
#Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                         "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ryotsu
# Processing Record 2 of Set 1 | sitka
# Processing Record 3 of Set 1 | asau
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | port alfred
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | salme
# Processing Record 9 of Set 1 | jamestown
# Processing Record 10 of Set 1 | faanui
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | atar
# Processing Record 13 of Set 1 | komsomolskiy
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | chaozhou
# Processing Record 16 of Set 1 | paamiut
# Processing Record 17 of Set 1 | vieste
# Processing Record 18 of Set 1 | ierapetra
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | fortuna
# Processing Record 21 of Set 1 | klaksvik
# Processing Record 22 of Set 1 | mahajanga
# Processing Record 23 of Set 1 | shimoda
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | mastic beach
# Processing Record 28 of Set 1 | puerto ayora
# Processing Record 29 of Set 1 | barcelona
# Processing Record 30 of Set 1 | saint-francois
# Processing Record 31 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 1 | hasaki
# Processing Record 33 of Set 1 | lexington
# Processing Record 34 of Set 1 | bengkulu
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 38 of Set 1 | ampanihy
# Processing Record 39 of Set 1 | masumbwe
# Processing Record 40 of Set 1 | kahta
# Processing Record 41 of Set 1 | olinda
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | bhikangaon
# Processing Record 44 of Set 1 | narsaq
# Processing Record 45 of Set 1 | port-gentil
# Processing Record 46 of Set 1 | serov
# Processing Record 47 of Set 1 | jibuti
# Processing Record 48 of Set 1 | shumikha
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | hamilton
# Processing Record 1 of Set 2 | maragogi
# Processing Record 2 of Set 2 | souillac
# Processing Record 3 of Set 2 | bantul
# Processing Record 4 of Set 2 | kapaa
# Processing Record 5 of Set 2 | nizhniy kuranakh
# Processing Record 6 of Set 2 | xichang
# Processing Record 7 of Set 2 | charters towers
# Processing Record 8 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 2 | le port
# Processing Record 10 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 2 | tecoanapa
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | tual
# Processing Record 15 of Set 2 | riyadh
# Processing Record 16 of Set 2 | kodiak
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | aripuana
# Processing Record 19 of Set 2 | deputatskiy
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | clyde river
# Processing Record 23 of Set 2 | nikolskoye
# Processing Record 24 of Set 2 | lavrentiya
# Processing Record 25 of Set 2 | touros
# Processing Record 26 of Set 2 | mapastepec
# Processing Record 27 of Set 2 | cape town
# Processing Record 28 of Set 2 | gewane
# Processing Record 29 of Set 2 | sobolevo
# Processing Record 30 of Set 2 | georgetown
# Processing Record 31 of Set 2 | tuatapere
# Processing Record 32 of Set 2 | pacific grove
# Processing Record 33 of Set 2 | tanabe
# Processing Record 34 of Set 2 | morondava
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | celestun
# Processing Record 38 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 2 | nantucket
# Processing Record 40 of Set 2 | bluff
# Processing Record 41 of Set 2 | taoudenni
# Processing Record 42 of Set 2 | santo antonio do taua
# Processing Record 43 of Set 2 | rawson
# Processing Record 44 of Set 2 | vila franca do campo
# Processing Record 45 of Set 2 | la rioja
# Processing Record 46 of Set 2 | ust-kuyga
# Processing Record 47 of Set 2 | verkhoyansk
# Processing Record 48 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 2 | mazamari
# Processing Record 50 of Set 2 | togur
# Processing Record 1 of Set 3 | pochutla
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | castro
# Processing Record 4 of Set 3 | kuala terengganu
# Processing Record 5 of Set 3 | buraydah
# Processing Record 6 of Set 3 | cabo san lucas
# Processing Record 7 of Set 3 | iqaluit
# Processing Record 8 of Set 3 | carutapera
# Processing Record 9 of Set 3 | saskylakh
# Processing Record 10 of Set 3 | bukachacha
# Processing Record 11 of Set 3 | ponta do sol
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | mount gambier
# Processing Record 14 of Set 3 | khorinsk
# Processing Record 15 of Set 3 | hirara
# Processing Record 16 of Set 3 | katsuura
# Processing Record 17 of Set 3 | hope
# Processing Record 18 of Set 3 | otradnoye
# Processing Record 19 of Set 3 | lasa
# Processing Record 20 of Set 3 | wuwei
# Processing Record 21 of Set 3 | nanpiao
# Processing Record 22 of Set 3 | yumen
# Processing Record 23 of Set 3 | sao jose do rio pardo
# Processing Record 24 of Set 3 | calabar
# Processing Record 25 of Set 3 | atuona
# Processing Record 26 of Set 3 | kardla
# Processing Record 27 of Set 3 | gardendale
# Processing Record 28 of Set 3 | naryan-mar
# Processing Record 29 of Set 3 | yarkovo
# Processing Record 30 of Set 3 | kalikapur
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | biak
# Processing Record 33 of Set 3 | beringovskiy
# Processing Record 34 of Set 3 | russell
# Processing Record 35 of Set 3 | new norfolk
# Processing Record 36 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 3 | valparaiso
# Processing Record 38 of Set 3 | kendari
# Processing Record 39 of Set 3 | arari
# Processing Record 40 of Set 3 | nome
# Processing Record 41 of Set 3 | candawaga
# City not found. Skipping...
# Processing Record 42 of Set 3 | richards bay
# Processing Record 43 of Set 3 | san quintin
# Processing Record 44 of Set 3 | jamame
# Processing Record 45 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 46 of Set 3 | avarua
# Processing Record 47 of Set 3 | chikoy
# City not found. Skipping...
# Processing Record 48 of Set 3 | amboasary
# Processing Record 49 of Set 3 | flinders
# Processing Record 50 of Set 3 | sarangani
# Processing Record 1 of Set 4 | domoni
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | naantali
# Processing Record 4 of Set 4 | pasinler
# Processing Record 5 of Set 4 | lebu
# Processing Record 6 of Set 4 | erzincan
# Processing Record 7 of Set 4 | qaanaaq
# Processing Record 8 of Set 4 | longyearbyen
# Processing Record 9 of Set 4 | palmer
# Processing Record 10 of Set 4 | husavik
# Processing Record 11 of Set 4 | bridgetown
# Processing Record 12 of Set 4 | codrington
# Processing Record 13 of Set 4 | pisco
# Processing Record 14 of Set 4 | korla
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | north bend
# Processing Record 17 of Set 4 | ostrovnoy
# Processing Record 18 of Set 4 | bindura
# Processing Record 19 of Set 4 | sao filipe
# Processing Record 20 of Set 4 | roebourne
# Processing Record 21 of Set 4 | tiznit
# Processing Record 22 of Set 4 | kutum
# Processing Record 23 of Set 4 | bethel
# Processing Record 24 of Set 4 | ozgon
# City not found. Skipping...
# Processing Record 25 of Set 4 | chuy
# Processing Record 26 of Set 4 | biltine
# Processing Record 27 of Set 4 | galgani
# City not found. Skipping...
# Processing Record 28 of Set 4 | padang
# Processing Record 29 of Set 4 | charlottesville
# Processing Record 30 of Set 4 | tiksi
# Processing Record 31 of Set 4 | esperance
# Processing Record 32 of Set 4 | ust-abakan
# Processing Record 33 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 4 | springbok
# Processing Record 35 of Set 4 | yaounde
# Processing Record 36 of Set 4 | presidente medici
# Processing Record 37 of Set 4 | sesheke
# Processing Record 38 of Set 4 | tazovskiy
# Processing Record 39 of Set 4 | provideniya
# Processing Record 40 of Set 4 | luderitz
# Processing Record 41 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 4 | uyemskiy
# Processing Record 43 of Set 4 | egvekinot
# Processing Record 44 of Set 4 | ndago
# Processing Record 45 of Set 4 | victoria
# Processing Record 46 of Set 4 | omsukchan
# Processing Record 47 of Set 4 | gujar khan
# Processing Record 48 of Set 4 | maldonado
# Processing Record 49 of Set 4 | neuquen
# Processing Record 50 of Set 4 | leningradskiy
# Processing Record 1 of Set 5 | kaoma
# Processing Record 2 of Set 5 | adrar
# Processing Record 3 of Set 5 | palombara sabina
# Processing Record 4 of Set 5 | vangaindrano
# Processing Record 5 of Set 5 | bambous virieux
# Processing Record 6 of Set 5 | torbay
# Processing Record 7 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 8 of Set 5 | chaman
# Processing Record 9 of Set 5 | ribeira grande
# Processing Record 10 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 11 of Set 5 | lodwar
# Processing Record 12 of Set 5 | achisay
# City not found. Skipping...
# Processing Record 13 of Set 5 | bathsheba
# Processing Record 14 of Set 5 | nawabganj
# Processing Record 15 of Set 5 | isangel
# Processing Record 16 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 5 | saravan
# Processing Record 18 of Set 5 | caravelas
# Processing Record 19 of Set 5 | cherskiy
# Processing Record 20 of Set 5 | olutanga
# Processing Record 21 of Set 5 | port macquarie
# Processing Record 22 of Set 5 | namie
# Processing Record 23 of Set 5 | acarau
# Processing Record 24 of Set 5 | sao mateus
# Processing Record 25 of Set 5 | moses lake
# Processing Record 26 of Set 5 | ca mau
# Processing Record 27 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 28 of Set 5 | semirom
# Processing Record 29 of Set 5 | aginskoye
# Processing Record 30 of Set 5 | sedelnikovo
# City not found. Skipping...
# Processing Record 31 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 5 | geraldton
# Processing Record 34 of Set 5 | constitucion
# Processing Record 35 of Set 5 | sredneuralsk
# Processing Record 36 of Set 5 | bandundu
# Processing Record 37 of Set 5 | axim
# Processing Record 38 of Set 5 | sao jose da coroa grande
# Processing Record 39 of Set 5 | acapulco
# Processing Record 40 of Set 5 | port blair
# Processing Record 41 of Set 5 | gigmoto
# Processing Record 42 of Set 5 | selma
# Processing Record 43 of Set 5 | vila velha
# Processing Record 44 of Set 5 | norman wells
# Processing Record 45 of Set 5 | mana
# Processing Record 46 of Set 5 | codajas
# Processing Record 47 of Set 5 | kenai
# Processing Record 48 of Set 5 | vao
# Processing Record 49 of Set 5 | hithadhoo
# Processing Record 50 of Set 5 | abay
# Processing Record 1 of Set 6 | huancabamba
# Processing Record 2 of Set 6 | bilma
# Processing Record 3 of Set 6 | huambo
# Processing Record 4 of Set 6 | hami
# Processing Record 5 of Set 6 | soyo
# Processing Record 6 of Set 6 | elat
# Processing Record 7 of Set 6 | te anau
# Processing Record 8 of Set 6 | necochea
# Processing Record 9 of Set 6 | galveston
# Processing Record 10 of Set 6 | bonthe
# Processing Record 11 of Set 6 | comodoro rivadavia
# Processing Record 12 of Set 6 | bonavista
# Processing Record 13 of Set 6 | mantua
# Processing Record 14 of Set 6 | skjaerhollen
# City not found. Skipping...
# Processing Record 15 of Set 6 | enzan
# Processing Record 16 of Set 6 | tasiilaq
# Processing Record 17 of Set 6 | olafsvik
# Processing Record 18 of Set 6 | sioux lookout
# Processing Record 19 of Set 6 | severo-kurilsk
# Processing Record 20 of Set 6 | kruisfontein
# Processing Record 21 of Set 6 | thai binh
# Processing Record 22 of Set 6 | filadelfia
# Processing Record 23 of Set 6 | otavi
# Processing Record 24 of Set 6 | koygorodok
# Processing Record 25 of Set 6 | mount isa
# Processing Record 26 of Set 6 | opuwo
# Processing Record 27 of Set 6 | bucak
# Processing Record 28 of Set 6 | chokurdakh
# Processing Record 29 of Set 6 | kaitangata
# Processing Record 30 of Set 6 | bar harbor
# Processing Record 31 of Set 6 | shenkursk
# Processing Record 32 of Set 6 | nardaran
# Processing Record 33 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 6 | srednekolymsk
# Processing Record 35 of Set 6 | zabid
# Processing Record 36 of Set 6 | umm lajj
# Processing Record 37 of Set 6 | ostersund
# Processing Record 38 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 39 of Set 6 | los llanos de aridane
# Processing Record 40 of Set 6 | duncan
# Processing Record 41 of Set 6 | glendive
# Processing Record 42 of Set 6 | aykhal
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | port elizabeth
# Processing Record 45 of Set 6 | bangangte
# Processing Record 46 of Set 6 | margate
# Processing Record 47 of Set 6 | naranjal
# Processing Record 48 of Set 6 | alice springs
# Processing Record 49 of Set 6 | noyabrsk
# Processing Record 50 of Set 6 | bignona
# Processing Record 1 of Set 7 | minas
# Processing Record 2 of Set 7 | saint-augustin
# Processing Record 3 of Set 7 | kenora
# Processing Record 4 of Set 7 | hambantota
# Processing Record 5 of Set 7 | luau
# Processing Record 6 of Set 7 | dejen
# Processing Record 7 of Set 7 | metehara
# City not found. Skipping...
# Processing Record 8 of Set 7 | hobyo
# Processing Record 9 of Set 7 | honiara
# Processing Record 10 of Set 7 | babushkin
# Processing Record 11 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 7 | mahebourg
# Processing Record 13 of Set 7 | klyuchi
# Processing Record 14 of Set 7 | gorno-altaysk
# Processing Record 15 of Set 7 | tamiahua
# Processing Record 16 of Set 7 | zaysan
# Processing Record 17 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 7 | bumba
# Processing Record 19 of Set 7 | oussouye
# Processing Record 20 of Set 7 | merauke
# Processing Record 21 of Set 7 | kavaratti
# Processing Record 22 of Set 7 | coihaique
# Processing Record 23 of Set 7 | saldanha
# Processing Record 24 of Set 7 | nouadhibou
# Processing Record 25 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 7 | carnarvon
# Processing Record 27 of Set 7 | dzilam gonzalez
# Processing Record 28 of Set 7 | chivilcoy
# Processing Record 29 of Set 7 | zhigansk
# Processing Record 30 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 31 of Set 7 | saint george
# Processing Record 32 of Set 7 | kiama
# Processing Record 33 of Set 7 | lagoa
# Processing Record 34 of Set 7 | nago
# Processing Record 35 of Set 7 | havoysund
# Processing Record 36 of Set 7 | vondrozo
# Processing Record 37 of Set 7 | port hardy
# Processing Record 38 of Set 7 | boende
# Processing Record 39 of Set 7 | thompson
# Processing Record 40 of Set 7 | gat
# Processing Record 41 of Set 7 | la macarena
# Processing Record 42 of Set 7 | washington
# Processing Record 43 of Set 7 | liliani
# Processing Record 44 of Set 7 | eureka
# Processing Record 45 of Set 7 | kodinsk
# Processing Record 46 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 47 of Set 7 | rio grande
# Processing Record 48 of Set 7 | milkovo
# Processing Record 49 of Set 7 | vardo
# Processing Record 50 of Set 7 | varzea grande
# Processing Record 1 of Set 8 | la ronge
# Processing Record 2 of Set 8 | evensk
# Processing Record 3 of Set 8 | birin
# Processing Record 4 of Set 8 | casino
# Processing Record 5 of Set 8 | colares
# Processing Record 6 of Set 8 | rafsanjan
# Processing Record 7 of Set 8 | stephenville
# Processing Record 8 of Set 8 | udachnyy
# Processing Record 9 of Set 8 | zeya
# Processing Record 10 of Set 8 | fukue
# Processing Record 11 of Set 8 | asyut
# Processing Record 12 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 8 | kahului
# Processing Record 14 of Set 8 | cairns
# Processing Record 15 of Set 8 | aksu
# Processing Record 16 of Set 8 | bandeirantes
# Processing Record 17 of Set 8 | tura
# Processing Record 18 of Set 8 | kupang
# Processing Record 19 of Set 8 | hualmay
# Processing Record 20 of Set 8 | novobirilyussy
# Processing Record 21 of Set 8 | abu dhabi
# Processing Record 22 of Set 8 | gornopravdinsk
# Processing Record 23 of Set 8 | ruidoso
# Processing Record 24 of Set 8 | kholodnyy
# Processing Record 25 of Set 8 | yamada
# Processing Record 26 of Set 8 | changping
# Processing Record 27 of Set 8 | mao
# Processing Record 28 of Set 8 | macamic
# Processing Record 29 of Set 8 | fare
# Processing Record 30 of Set 8 | arlit
# Processing Record 31 of Set 8 | mecca
# Processing Record 32 of Set 8 | shaki
# Processing Record 33 of Set 8 | chifeng
# Processing Record 34 of Set 8 | tabulbah
# City not found. Skipping...
# Processing Record 35 of Set 8 | shache
# Processing Record 36 of Set 8 | turka
# Processing Record 37 of Set 8 | xiuyan
# Processing Record 38 of Set 8 | ozinki
# Processing Record 39 of Set 8 | namatanai
# Processing Record 40 of Set 8 | kavieng
# Processing Record 41 of Set 8 | mamallapuram
# Processing Record 42 of Set 8 | orchard homes
# Processing Record 43 of Set 8 | badaojiang
# City not found. Skipping...
# Processing Record 44 of Set 8 | natchez
# Processing Record 45 of Set 8 | hinton
# Processing Record 46 of Set 8 | great yarmouth
# Processing Record 47 of Set 8 | fairbanks
# Processing Record 48 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 8 | gizo
# Processing Record 50 of Set 8 | bandarbeyla
# Processing Record 1 of Set 9 | san patricio
# Processing Record 2 of Set 9 | tabou
# Processing Record 3 of Set 9 | broome
# Processing Record 4 of Set 9 | agucadoura
# Processing Record 5 of Set 9 | qasigiannguit
# Processing Record 6 of Set 9 | raudeberg
# Processing Record 7 of Set 9 | grand gaube
# Processing Record 8 of Set 9 | himora
# City not found. Skipping...
# Processing Record 9 of Set 9 | northam
# Processing Record 10 of Set 9 | luan
# Processing Record 11 of Set 9 | pangnirtung
# Processing Record 12 of Set 9 | manzanillo
# Processing Record 13 of Set 9 | sumoto
# Processing Record 14 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 9 | ous
# Processing Record 16 of Set 9 | fort-shevchenko
# Processing Record 17 of Set 9 | les cayes
# Processing Record 18 of Set 9 | hokitika
# Processing Record 19 of Set 9 | antofagasta
# Processing Record 20 of Set 9 | vanimo
# Processing Record 21 of Set 9 | vuktyl
# Processing Record 22 of Set 9 | ilulissat
# Processing Record 23 of Set 9 | whitehorse
# Processing Record 24 of Set 9 | almaznyy
# Processing Record 25 of Set 9 | luanda
# Processing Record 26 of Set 9 | saint anthony
# Processing Record 27 of Set 9 | san cristobal
# Processing Record 28 of Set 9 | chara
# Processing Record 29 of Set 9 | nouakchott
# Processing Record 30 of Set 9 | kayerkan
# Processing Record 31 of Set 9 | ximei
# Processing Record 32 of Set 9 | oparino
# Processing Record 33 of Set 9 | nishihara
# Processing Record 34 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 9 | cascais
# Processing Record 36 of Set 9 | saint-pierre
# Processing Record 37 of Set 9 | nikolayevsk-na-amure
# Processing Record 38 of Set 9 | palembang
# Processing Record 39 of Set 9 | harrisburg
# Processing Record 40 of Set 9 | berlevag
# Processing Record 41 of Set 9 | rosetta
# Processing Record 42 of Set 9 | ayan
# Processing Record 43 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 44 of Set 9 | campos gerais
# Processing Record 45 of Set 9 | gasa
# Processing Record 46 of Set 9 | upernavik
# Processing Record 47 of Set 9 | roscommon
# Processing Record 48 of Set 9 | sao joao da barra
# Processing Record 49 of Set 9 | naze
# Processing Record 50 of Set 9 | emerald
# Processing Record 1 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 10 | ternate
# Processing Record 3 of Set 10 | jishu
# Processing Record 4 of Set 10 | dovers
# Processing Record 5 of Set 10 | copiapo
# Processing Record 6 of Set 10 | winnemucca
# Processing Record 7 of Set 10 | hay river
# Processing Record 8 of Set 10 | kyra
# Processing Record 9 of Set 10 | henties bay
# Processing Record 10 of Set 10 | gaomi
# Processing Record 11 of Set 10 | fort nelson
# Processing Record 12 of Set 10 | tigil
# Processing Record 13 of Set 10 | machiques
# Processing Record 14 of Set 10 | pevek
# Processing Record 15 of Set 10 | ancud
# Processing Record 16 of Set 10 | sur
# Processing Record 17 of Set 10 | praia da vitoria
# Processing Record 18 of Set 10 | georgiyevskoye
# Processing Record 19 of Set 10 | bage
# Processing Record 20 of Set 10 | galle
# Processing Record 21 of Set 10 | batman
# Processing Record 22 of Set 10 | kumba
# Processing Record 23 of Set 10 | manuk mangkaw
# Processing Record 24 of Set 10 | vestmannaeyjar
# Processing Record 25 of Set 10 | lompoc
# Processing Record 26 of Set 10 | rudbar
# Processing Record 27 of Set 10 | mae ramat
# Processing Record 28 of Set 10 | pandan
# Processing Record 29 of Set 10 | polaniec
# Processing Record 30 of Set 10 | nieuw amsterdam
# Processing Record 31 of Set 10 | miles city
# Processing Record 32 of Set 10 | santiago de cao
# Processing Record 33 of Set 10 | ossora
# Processing Record 34 of Set 10 | kulhudhuffushi
# Processing Record 35 of Set 10 | basco
# Processing Record 36 of Set 10 | coquimbo
# Processing Record 37 of Set 10 | cockburn town
# Processing Record 38 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 39 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 40 of Set 10 | penalva
# Processing Record 41 of Set 10 | calama
# Processing Record 42 of Set 10 | shostka
# Processing Record 43 of Set 10 | vila
# Processing Record 44 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 10 | miracema do tocantins
# Processing Record 46 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 47 of Set 10 | boyolangu
# Processing Record 48 of Set 10 | pemangkat
# Processing Record 49 of Set 10 | cornwall
# Processing Record 50 of Set 10 | hearst
# Processing Record 1 of Set 11 | kundiawa
# Processing Record 2 of Set 11 | manaus
# Processing Record 3 of Set 11 | malinao
# Processing Record 4 of Set 11 | makinsk
# Processing Record 5 of Set 11 | trairi
# Processing Record 6 of Set 11 | bilibino
# Processing Record 7 of Set 11 | tyrma
# Processing Record 8 of Set 11 | noumea
# Processing Record 9 of Set 11 | domna
# Processing Record 10 of Set 11 | rancharia
# Processing Record 11 of Set 11 | mehamn
# Processing Record 12 of Set 11 | sola
# Processing Record 13 of Set 11 | atasu
# Processing Record 14 of Set 11 | lucea
# Processing Record 15 of Set 11 | bykovo
# Processing Record 16 of Set 11 | goderich
# Processing Record 17 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 18 of Set 11 | malanje
# Processing Record 19 of Set 11 | kaa-khem
# Processing Record 20 of Set 11 | okha
# Processing Record 21 of Set 11 | garden city
# Processing Record 22 of Set 11 | alibag
# Processing Record 23 of Set 11 | mangan
# Processing Record 24 of Set 11 | kuruman
# Processing Record 25 of Set 11 | honningsvag
# Processing Record 26 of Set 11 | mokolo
# Processing Record 27 of Set 11 | bubaque
# Processing Record 28 of Set 11 | uvira
# Processing Record 29 of Set 11 | pecos
# Processing Record 30 of Set 11 | arkhangelos
# City not found. Skipping...
# Processing Record 31 of Set 11 | priargunsk
# Processing Record 32 of Set 11 | susehri
# Processing Record 33 of Set 11 | yar-sale
# Processing Record 34 of Set 11 | saint-marc-des-carrieres
# Processing Record 35 of Set 11 | nirmal
# Processing Record 36 of Set 11 | christchurch
# Processing Record 37 of Set 11 | yanam
# Processing Record 38 of Set 11 | alofi
# Processing Record 39 of Set 11 | haines junction
# Processing Record 40 of Set 11 | matara
# Processing Record 41 of Set 11 | norsup
# Processing Record 42 of Set 11 | olivenza
# Processing Record 43 of Set 11 | smithers
# Processing Record 44 of Set 11 | kamenka
# Processing Record 45 of Set 11 | hofn
# Processing Record 46 of Set 11 | shaowu
# Processing Record 47 of Set 11 | tabat
# Processing Record 48 of Set 11 | papara
# Processing Record 49 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 50 of Set 11 | keene
# Processing Record 1 of Set 12 | aklavik
# Processing Record 2 of Set 12 | neiafu
# Processing Record 3 of Set 12 | toora-khem
# Processing Record 4 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 12 | gao
# Processing Record 7 of Set 12 | shubarshi
# Processing Record 8 of Set 12 | jardim
# Processing Record 9 of Set 12 | serowe
# Processing Record 10 of Set 12 | beitbridge
# Processing Record 11 of Set 12 | passagem franca
# Processing Record 12 of Set 12 | nanortalik
# Processing Record 13 of Set 12 | sompeta
# Processing Record 14 of Set 12 | mareeba
# Processing Record 15 of Set 12 | okhotsk
# Processing Record 16 of Set 12 | tadine
# Processing Record 17 of Set 12 | alta floresta
# Processing Record 18 of Set 12 | polyarnyy
# Processing Record 19 of Set 12 | plakhtiyivka
# Processing Record 20 of Set 12 | hashtrud
# Processing Record 21 of Set 12 | requena
# Processing Record 22 of Set 12 | oktyabrskiy
# Processing Record 23 of Set 12 | samarai
# Processing Record 24 of Set 12 | yulara
# Processing Record 25 of Set 12 | madang
# Processing Record 26 of Set 12 | the valley
# Processing Record 27 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 12 | nalut
# Processing Record 29 of Set 12 | araguacu
# Processing Record 30 of Set 12 | prince albert
# Processing Record 31 of Set 12 | buy
# Processing Record 32 of Set 12 | asfi
# Processing Record 33 of Set 12 | gamba
# Processing Record 34 of Set 12 | nam dinh
# Processing Record 35 of Set 12 | wasilla
# Processing Record 36 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 12 | clarence town
# Processing Record 38 of Set 12 | ahipara
# Processing Record 39 of Set 12 | zavodoukovsk
# Processing Record 40 of Set 12 | kharp
# Processing Record 41 of Set 12 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 12 | oktyabrskoye
# Processing Record 43 of Set 12 | nelson bay
# Processing Record 44 of Set 12 | gemena
# Processing Record 45 of Set 12 | xai-xai
# Processing Record 46 of Set 12 | narodychi
# Processing Record 47 of Set 12 | grindavik
# Processing Record 48 of Set 12 | lepley
# Processing Record 49 of Set 12 | muravlenko
# Processing Record 50 of Set 12 | waingapu
# Processing Record 1 of Set 13 | belgrade
# Processing Record 2 of Set 13 | montepuez
# Processing Record 3 of Set 13 | nsanje
# Processing Record 4 of Set 13 | whitianga
# Processing Record 5 of Set 13 | tautira
# Processing Record 6 of Set 13 | casale monferrato
# Processing Record 7 of Set 13 | rabaul
# Processing Record 8 of Set 13 | santiago del estero
# Processing Record 9 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 13 | bobonong
# City not found. Skipping...
# Processing Record 11 of Set 13 | voh
# Processing Record 12 of Set 13 | chipinge
# Processing Record 13 of Set 13 | safranbolu
# Processing Record 14 of Set 13 | teknaf
# Processing Record 15 of Set 13 | rock sound
# Processing Record 16 of Set 13 | marzuq
# Processing Record 17 of Set 13 | shingu
# Processing Record 18 of Set 13 | puerto del rosario
# Processing Record 19 of Set 13 | turiacu
# Processing Record 20 of Set 13 | ntcheu
# Processing Record 21 of Set 13 | saint-georges
# Processing Record 22 of Set 13 | inhambane
# Processing Record 23 of Set 13 | quang ngai
# Processing Record 24 of Set 13 | benjamin aceval
# Processing Record 25 of Set 13 | irati
# Processing Record 26 of Set 13 | keti bandar
# Processing Record 27 of Set 13 | chicama
# Processing Record 28 of Set 13 | porto novo
# Processing Record 29 of Set 13 | aguilas
# Processing Record 30 of Set 13 | batagay
# Processing Record 31 of Set 13 | kyshtovka
# Processing Record 32 of Set 13 | susah
# City not found. Skipping...
# Processing Record 33 of Set 13 | xining
# Processing Record 34 of Set 13 | berbera
# Processing Record 35 of Set 13 | mopti
# Processing Record 36 of Set 13 | araquari
# Processing Record 37 of Set 13 | port lincoln
# Processing Record 38 of Set 13 | bintulu
# Processing Record 39 of Set 13 | kudahuvadhoo
# Processing Record 40 of Set 13 | itoman
# Processing Record 41 of Set 13 | half moon bay
# Processing Record 42 of Set 13 | kalat
# Processing Record 43 of Set 13 | krasnomayskiy
# Processing Record 44 of Set 13 | sorong
# Processing Record 45 of Set 13 | talnakh
# Processing Record 46 of Set 13 | newcastle
# Processing Record 47 of Set 13 | yandoon
# City not found. Skipping...
# Processing Record 48 of Set 13 | suzun
# Processing Record 49 of Set 13 | zhanaozen
# Processing Record 50 of Set 13 | arkhipo-osipovka
# Processing Record 1 of Set 14 | kabo
# Processing Record 2 of Set 14 | quatre cocos
# Processing Record 3 of Set 14 | sento se
# City not found. Skipping...
# Processing Record 4 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 14 | kalimnos
# City not found. Skipping...
# Processing Record 6 of Set 14 | linchuan
# City not found. Skipping...
# Processing Record 7 of Set 14 | banjar
# Processing Record 8 of Set 14 | dosso
# Processing Record 9 of Set 14 | katiola
# Processing Record 10 of Set 14 | sambava
# Processing Record 11 of Set 14 | port augusta
# Processing Record 12 of Set 14 | kokopo
# Processing Record 13 of Set 14 | karakendzha
# City not found. Skipping...
# Processing Record 14 of Set 14 | lindsay
# Processing Record 15 of Set 14 | dudinka
# Processing Record 16 of Set 14 | tolaga bay
# Processing Record 17 of Set 14 | boundiali
# Processing Record 18 of Set 14 | pudozh
# Processing Record 19 of Set 14 | angelopolis
# Processing Record 20 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 21 of Set 14 | nemuro
# Processing Record 22 of Set 14 | sulam
# Processing Record 23 of Set 14 | guerrero negro
# Processing Record 24 of Set 14 | florianopolis
# Processing Record 25 of Set 14 | baglan
# Processing Record 26 of Set 14 | puerto cabezas
# Processing Record 27 of Set 14 | arras
# Processing Record 28 of Set 14 | temir
# Processing Record 29 of Set 14 | barichara
# Processing Record 30 of Set 14 | ilek
# Processing Record 31 of Set 14 | mandalgovi
# Processing Record 32 of Set 14 | menomonie
# Processing Record 33 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 34 of Set 14 | cayenne
# Processing Record 35 of Set 14 | san martin
# Processing Record 36 of Set 14 | bjornevatn
# Processing Record 37 of Set 14 | porto walter
# Processing Record 38 of Set 14 | simao
# Processing Record 39 of Set 14 | nassau
# Processing Record 40 of Set 14 | harper
# Processing Record 41 of Set 14 | ust-tsilma
# Processing Record 42 of Set 14 | dunmore town
# Processing Record 43 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 44 of Set 14 | mae tha
# Processing Record 45 of Set 14 | makakilo city
# Processing Record 46 of Set 14 | livingstone
# Processing Record 47 of Set 14 | mayo
# Processing Record 48 of Set 14 | khash
# Processing Record 49 of Set 14 | sinnamary
# Processing Record 50 of Set 14 | kushmurun
# Processing Record 1 of Set 15 | jalu
# Processing Record 2 of Set 15 | redmond
# Processing Record 3 of Set 15 | moron
# Processing Record 4 of Set 15 | odienne
# Processing Record 5 of Set 15 | vanavara
# Processing Record 6 of Set 15 | punta alta
# Processing Record 7 of Set 15 | betong
# Processing Record 8 of Set 15 | khandyga
# Processing Record 9 of Set 15 | kamaishi
# Processing Record 10 of Set 15 | pitimbu
# Processing Record 11 of Set 15 | takoradi
# Processing Record 12 of Set 15 | severnyy-kospashskiy
# Processing Record 13 of Set 15 | balabac
# Processing Record 14 of Set 15 | lorengau
# Processing Record 15 of Set 15 | sungaipenuh
# Processing Record 16 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 15 | mitsamiouli
# Processing Record 18 of Set 15 | morant bay
# Processing Record 19 of Set 15 | bundaberg
# Processing Record 20 of Set 15 | pyay
# Processing Record 21 of Set 15 | viedma
# Processing Record 22 of Set 15 | kalmunai
# Processing Record 23 of Set 15 | kemijarvi
# Processing Record 24 of Set 15 | shizunai
# Processing Record 25 of Set 15 | portland
# Processing Record 26 of Set 15 | bodrum
# Processing Record 27 of Set 15 | puerto penasco
# Processing Record 28 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 29 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 30 of Set 15 | springfield
# Processing Record 31 of Set 15 | murray bridge
# Processing Record 32 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 33 of Set 15 | yaan
# Processing Record 34 of Set 15 | jiangyou
# Processing Record 35 of Set 15 | kallaste
# Processing Record 36 of Set 15 | elk
# Processing Record 37 of Set 15 | vernon
# Processing Record 38 of Set 15 | na klang
# Processing Record 39 of Set 15 | a
# City not found. Skipping...
# Processing Record 40 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 15 | dwarka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 670

# %%
#Create a DataFrame of City Weather Data by converting the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(15)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ryotsu      JP  38.0833  138.4333     60.40        58          34
# 1          Sitka      US  57.0531 -135.3300     46.29        76          90
# 2           Asau      RO  46.4333   26.4000     43.75        79          20
# 3         Albany      US  42.6001  -73.9662     52.81        71          98
# 4    Port Alfred      ZA -33.5906   26.8910     66.78        84         100
# 5         Barrow      US  71.2906 -156.7887     21.22        86          90
# 6          Salme      NP  28.0369   85.0942     52.09        64           0
# 7      Jamestown      US  42.0970  -79.2353     51.12        89           1
# 8         Faanui      PF -16.4833 -151.7500     80.01        77          66
# 9      Busselton      AU -33.6500  115.3333     49.05        74          86
# 10          Atar      MR  20.5169  -13.0499     78.15        50          98
# 11  Komsomolskiy      UZ  40.4272   71.7189     48.92        57         100
# 12       Ushuaia      AR -54.8000  -68.3000     47.86        57          20
# 13      Chaozhou      CN  23.6651  116.6379     70.93        88          77
# 14       Paamiut      GL  61.9940  -49.6678     31.21        70          49
#
#     Wind Speed       Description
# 0        10.65  scattered clouds
# 1         9.22        light rain
# 2         4.32        few clouds
# 3         5.57   overcast clouds
# 4        31.90   overcast clouds
# 5         4.61   overcast clouds
# 6         6.71         clear sky
# 7         1.01         clear sky
# 8         6.26        light rain
# 9         9.48   overcast clouds
# 10        4.14   overcast clouds
# 11        6.91              haze
# 12       19.57        few clouds
# 13        2.10        light rain
# 14       13.80  scattered clouds

# %%
# Create the output file (CSV).
# Export the City_Data into a CSV.
city_data_df.to_csv('WeatherPy_Database.csv')
